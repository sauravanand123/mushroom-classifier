# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\anand\Videos\sulabh sir python\Mushroom Classification dataset.zip')
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['class'],df['cap-shape'])

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
df.habitat.values
# Out:
# array(['u', 'g', 'm', ..., 'l', 'l', 'l'], dtype=object)

# %%
df['class'].value_counts()
# Out:
# class
# e    4208
# p    3916
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
import seaborn as sb

# %%
for i in df.columns:
    sb.boxplot(df[i])
    plt.show()

# %%
import numpy as np

# %%
def remove_outliers(df):
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = np.percentile(df, 25)
    Q3 = np.percentile(df, 75)
    
    # Compute the Interquartile Range (IQR)
    IQR = Q3 - Q1
    
    # Define the bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Filter out the outliers
    filtered_data = df[(df >= lower_bound) & (df <= upper_bound)]
    
    return filtered_data

# Example usage
filtered_data = remove_outliers(df)

print("Original Data:", df)
print("Filtered Data:", filtered_data)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[28], line 19
#      16     return filtered_data
#      18 # Example usage
# ---> 19 filtered_data = remove_outliers(df)
#      21 print("Original Data:", df)
#      22 print("Filtered Data:", filtered_data)
#
# Cell In[28], line 3, in remove_outliers(df)
#       1 def remove_outliers(df):
#       2     # Calculate Q1 (25th percentile) and Q3 (75th percentile)
# ----> 3     Q1 = np.percentile(df, 25)
#       4     Q3 = np.percentile(df, 75)
#       6     # Compute the Interquartile Range (IQR)
#
# File c:\Users\anand\OneDrive\Desktop\expriencepwskills\Mushroom Classification\venv\lib\site-packages\numpy\lib\_function_base_impl.py:4287, in percentile(a, q, axis, out, overwrite_input, method, keepdims, weights, interpolation)
#    4284     if np.any(weights < 0):
# ...

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
x=df['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']
y=df['class']



x_train,y_train,x_test,y_test= train_test_split(x,y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\anand\OneDrive\Desktop\expriencepwskills\Mushroom Classification\venv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
l3=[111,222,333,444,555,666,777,888,999,1000]
l1=[2,3,4,5,7,8,7,6,4,3]
l2=[11,22,33,44,55,66,77,88,99,11]

x_train,y_train,x_test,y_test= train_test_split(['l1','l3'],l2, random_state=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 5
#       2 l1=[2,3,4,5,7,8,7,6,4,3]
#       3 l2=[11,22,33,44,55,66,77,88,99,11]
# ----> 5 x_train,y_train,x_test,y_test= train_test_split(['l1','l3'],l2, random_state=3)
#
# File c:\Users\anand\OneDrive\Desktop\expriencepwskills\Mushroom Classification\venv\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
# ...

# %%
y_test
# Out:
# [66, 55, 22]
